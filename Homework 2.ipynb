# %%
# %matplotlib inline
import pandas as pd
import numpy
import matplotlib.pyplot as plt
import re
import datetime
import sklearn

# %%
#note to self: opening a csv file in excel may corrupt the data!
data = pd.read_csv('../invoices.csv')
data.head()
# Out:
#         id                 date  subtotal  freight    tax   total  discount  \
# 0  1012516  2016-07-05 16:16:04     313.5      0.0  47.03  360.53       0.0
# 1  1012515  2016-07-05 16:15:53     166.0      0.0  24.90  190.90       0.0
# 2  1012514  2016-07-05 00:00:00     -17.5      0.0  -2.63  -20.13       0.0
# 3  1012513  2016-07-05 00:00:00     180.0      5.0  27.75  212.75       0.0
# 4  1012512  2016-07-05 00:00:00      97.0      8.0  15.75  120.75       0.0
#
#    paid  delivered  order_id  cust_id           cust_name  deleted  \
# 0     0          1      5843      218  The Accessory Shop        0
# 1     0          1      5842     2527      Palmers Napier        0
# 2     0          1         0     1604       Bettie Monroe        0
# 3     0          1      5841     2630             Habitat        0
# 4     0          1         0     1693        Cottage Lane        0
#
#                                             contents  bk_order_id     type  \
# 0  [{"rowid":"894db62f7b7a6ed2f2a277dae56a017c","...            0  invoice
# 1  [{"rowid":"a09e75c5c86a7bf6582d2b4d75aad615","...            0  invoice
# 2  [{"name":"CM-11 (CREDIT)","qty":"-1","price":"...            0  invoice
# 3  [{"rowid":"da94cbeff56cfda50785df477941308b","...            0  invoice
# 4  [{"rowid":"20546457187cf3d52ea86538403e47cc","...            0  invoice
#
#     sales purchase_info
# 0     NaN           NaN
# 1     NaN           NaN
# 2  Others        CREDIT
# 3    Lois    ONLINE5841
# 4   Helen             D

# %%
len(data)
# Out:
# 6410

# %%
##Ignore this! I was trying to pass a json object by parsing it as a string... bad idea
#1st attempt: breaking down the 'contents column', to find what products customers are ordering
#the order data is captured in a string.
# f1 = data.contents[0]
# #take away the punctuation at the beginning and end
# f2 = f1[2:-2]
# #split the string into substrings for each row, and put into a series
# order_array = f2.split("},{")
# order_series = pd.Series(data = order_array)
# order_series[0]

# %%
#code for processing each 'contents' row...
#def get_contents_df(order_series):
# rowid = pd.Series()
# did = pd.Series()
# qty = pd.Series()
# price = pd.Series()
# name = pd.Series()
# discount = pd.Series()
# subtotal = pd.Series()
# count = 0
# for row in range (0, order_series.size):
#     a = order_series[row].split(',')
#     d_array = []
#     #collect data and add show to dataframe
#     for dp in a:      
#         #this accounts for the last row which is a bit weird
#         if (dp == a[len(a)-1]):
#             d2 = re.search(r'(\"\:)(.*\d)', dp)
#             d2a = d2.group(2)
#             d_array.append(d2a)
#         else:
#             d = re.search(r'(\:\")(.+\")', dp)
#             da = d.group(2)[0:-1]
#             d_array.append(da)
#         #collect all indexes for the Dataframe
#         #i = re.search(r'(\w+)(\"\:)', dp)
#         #if i.group(1) in idx:
#         #    break
#         #else:
#         #    idx.append(i.group(1))
#     if (len(d_array)<=4):
#         break
#     else:
#         rowid.set_value(count, d_array[0])
#         did.set_value(count, d_array[1])
#         qty.set_value(count, d_array[2])
#         price.set_value(count, d_array[3])
#         name.set_value(count, d_array[4])
#         discount.set_value(count, d_array[5])
#         subtotal.set_value(count, d_array[6])

#     count = count+1

# df_data = {'rowid': rowid, 'id':did, 'qty':qty, 'price':price, 'name':name, 'discount':discount, 'subtotal':subtotal}
# order_df = pd.DataFrame(df_data)
# order_df
#return order_df

# %%
# df_temp = pd.DataFrame()
# latest_20 = data.head(20)
# #for order in range (0, len(latest_20)):
# for order in range (0, 1):
#     f1 = latest_20.contents[order]
#     #take away the punctuation at the beginning and end
#     f2 = f1[2:-2]
#     #split the string into substrings for each row, and put into a series
#     order_array = f2.split("},{")
#     order_ss = pd.Series(data = order_array)
#     filtered_order_ss = order_ss.drop([30]).reset_index().ix[:,1]
#     print filtered_order_ss
#     df_temp = get_contents_df(order_ss)
#     df_temp['orderid'] = latest_20.id[order]
#     #dataframe = get_contents_df(filtered_order_ss)
#     #dataframe['orderid'] = latest_20.id[order]
#     #print "i've finished invoice:"
#     #print order
    
# df_temp

# %%
import json

# %%
test = json.loads(data.contents[0])

# %%
#Goal: make new dataframe of all orders - Caution this can take a while
#and add new columns for each order detailing which order number and customer it was from
df_orders = pd.DataFrame(test)
df_orders['order_id'] = data.id[i]
df_orders['cust_id'] = data.cust_id[i]
#for i in range (1, 5):
for i in range (1, len(data)-1):
    orders = json.loads(data.contents[i])
    temp_df = pd.DataFrame(orders)
    #add order id & customer id
    temp_df['order_id'] = data.id[i]
    temp_df['cust_id'] = data.cust_id[i]
    df_orders = df_orders.append(temp_df)
df_orders.head()
# Out:
#    cust_id discount    id       name  order_id  price qty  \
# 0     2158        0  2860      CM-10   1006559  17.50   1
# 1     2158        0  2175       CM-1   1006559  17.50   1
# 2     2158        0  2787       CM-8   1006559  17.50   1
# 3     2158        0  2601  CMYH-BT-4   1006559  17.50   1
# 4     2158        0  3296     CYM-54   1006559  17.00   1
#
#                               rowid  subtotal
# 0  894db62f7b7a6ed2f2a277dae56a017c      17.5
# 1  211c1e0b83b9c69fa9c4bdede203c1e3      17.5
# 2  2e0bff759d057e28460eaa5b2cb118e5      17.5
# 3  e02e27e04fdff967ba7d76fb24b8069d      17.5
# 4  42cd63cb189c30ed03e42ce2c069566c      17.0

# %%
df_orders.reset_index()
# Out:
#         index  cust_id discount    id          name  order_id  price qty  \
# 0           0     2158        0  2860         CM-10   1006559  17.50   1
# 1           1     2158        0  2175          CM-1   1006559  17.50   1
# 2           2     2158        0  2787          CM-8   1006559  17.50   1
# 3           3     2158        0  2601     CMYH-BT-4   1006559  17.50   1
# 4           4     2158        0  3296        CYM-54   1006559  17.00   1
# 5           5     2158        0  3297        CYM-81   1006559  17.00   1
# 6           6     2158        0  3287         CYM-2   1006559  17.00   1
# 7           7     2158        0  3292        CYM-12   1006559  17.00   1
# 8           8     2158        0  3293        CYM-13   1006559  17.00   1
# 9           9     2158        0  4996        FW2-54   1006559   5.50   1
# 10         10     2158        0  4989         FW2-8   1006559   5.50   1
# 11         11     2158        0  4997        FW2-81   1006559   5.50   1
# 12         12     2158        0  1662      FP-H-53    1006559   6.00   3
# 13         13     2158        0  1434        FP-H-8   1006559   6.00   2
# 190308  70fc5f043205720a49d973d280eb83e7      12.0
# 190309  394868456436dbe743e4380554c0493a      12.0
# 190310  c79ec57a8e72a87d8a69d2c6b8a2a8d4      12.0
# 190311  6098ed616e715171f0dabad60a8e5197      12.0
# 190312  7dc3338d429a3114842ca29dbbfccfef      12.0
# 190313  5bf8aaef51c6e0d363cbe554acaf3f20      12.0
# 190314  1b69ebedb522700034547abc5652ffac      12.0
# 190315  b986700c627db479a4d9460b75de7222      12.0
# 190316  032dd17b77fab7d51a476c5ff2b5659c       3.0
# 190317  97275a23ca44226c9964043c8462be96      10.0
#
# [190318 rows x 10 columns]

# %%
#check that there are the same number of invoices, initially 6410 invoices
len(df_orders.groupby('order_id'))
# Out:
# 6408

# %%
#how many products do we have?
products = df_orders.groupby('name')
len(products)
# Out:
# 8668

# %%
#how many of each product?
product_df = pd.Series(products.size())
#let's get the top 100 products
top_products = product_df.sort_values(ascending=False).head(100)
top_products
# Out:
# name
#  Rural Ticket    353
# DXWB-53          306
# MDD-82-9         272
# MDD-8            269
# MDD-9-82         258
# DXWB-8           256
# DXWB-32          235
# SGM-SN-82        233
# MDD-4-9          232
# SGM-SN-53        232
# MDD-54-9         230
# MDD-9-32         228
# MDD-9-53         224
# MDD-1-9          223
# MDD-12-9         218
# SGM-SN-8         212
# MDD-53-9         203
# FGR-54           199
# FGR-8            198
# MDD-9-1          195
# DXWB-81          195
# CUSHION INNER    193
# FGR-82           192
# DXWB-11          191
# MDD-2-9          184
# SGM-SN-11        182
# SR-MTY-13        178
# MDD-1            178
# MMD-8            177
# SGM-SN-4         174
#                 ...
# BLS-DD-9         143
# FGR-71           142
# YRWB-DG-8        142
# BLS-DD-32        142
# BLS-DD-10        141
# BLS-CD-5         140
# SR-MTY-10        140
# MDD-8-9          139
# FGR-52           137
# BLS-DD-11        137
# MDD-13           137
# MDR-JB-31        137
# FGR-CT-4         136
# MDR-51           136
# BLS-YS-54        136
# BLS-TYH-53       135
# SR-MTY-53        135
# BLS-CD-2         135
# BLS-MTY-8        135
# WB-SBL-41        135
# BLS-TYH-8        134
# FGR-CT-1         133
# BLS-XT-82        133
# MKR-9-82         133
# MKR-1            132
# YRWB-DG-54       131
# BLS-YS-8         131
# DDBT-12          131
# SR-TYH-53        130
# WB-SBL-11        129
# dtype: int64

# %%
#I want to look at

# %%
#select all data from July 2016
jun2016 = data[data.date.str.contains("2016-06")]
jun2016
# Out:
#           id                 date  subtotal  freight     tax    total  \
# 39   1012475  2016-06-30 00:00:00      80.0      8.0   13.20   101.20
# 42   1012472  2016-06-30 00:00:00      41.5      5.0    6.98    53.48
# 45   1012469  2016-06-30 00:00:00     130.0      7.0   20.55   157.55
# 48   1012466  2016-06-30 00:00:00      32.0      7.0    5.85    44.85
# 50   1012464  2016-06-29 00:00:00      81.0      8.0   13.35   102.35
# 55   1012459  2016-06-29 00:00:00      56.0      8.0    9.60    73.60
# 56   1012458  2016-06-29 00:00:00     149.5     12.0   24.23   185.73
# 64   [{"rowid":"1680e9fa7b4dd5d62ece800239bb53bd","...      2002930  invoice
# 65   [{"name":"ZSHY-BW-82","qty":"-1","price":"10.0...            0  invoice
# 66   [{"rowid":"b22ed7eafe03b63112ef3ff52f0b99db","...            0  invoice
# 68   [{"rowid":"6e616e79d491ba42638558caf0364003","...      2002929  invoice
# 69   [{"name":"HGTY-82","qty":"-1","price":"15.00",...            0  invoice
# 70   [{"name":"CMYH-MG-1","qty":"-1","price":"17.50...            0  invoice
# 71   [{"rowid":"b65f2ecd2900ba6ae49a14d9c4b16fb4","...      2002928  invoice
# 72   [{"rowid":"4772c1b987f1f6d8c9d4ef0f3b764f7a","...            0  invoice
# 73   [{"rowid":"90e1357833654983612fb05e3ec9148c","...            0  invoice
# 75   [{"rowid":"77305c2f862ad1d353f55bf38e5a5183","...      2002927  invoice
# 76   [{"rowid":"4928e7510f45da6575b04a28519c09ed","...      2002926  invoice
# 79   [{"rowid":"d714d2c5a796d5814c565d78dd16188d","...      2002924  invoice
# 80   [{"rowid":"f1981e4bd8a0d6d8462016d2fc6276b3","...      2002923  invoice
# 81   [{"rowid":"a8f8f60264024dca151f164729b76c0b","...            0  invoice
# 82   [{"rowid":"6d9c547cf146054a5a720606a7694467","...            0  invoice
# 84   [{"rowid":"1f1baa5b8edac74eb4eaa329f14a0361","...            0  invoice
# 85   [{"rowid":"4a06d868d044c50af0cf9bc82d2fc19f","...            0  invoice
# 86   [{"rowid":"4aec1b3435c52abbdf8334ea0e7141e0","...            0  invoice
# 87   [{"rowid":"7503cfacd12053d309b6bed5c89de212","...            0  invoice
# 89   [{"rowid":"6f3e29a35278d71c7f65495871231324","...            0  invoice
# ..                                                 ...          ...      ...
# 478  [{"rowid":"5dd3e474f6e08e3316ce5e3bc36c666e","...            0  invoice
# 489  [{"rowid":"f507783927f2ec2737ba40afbd17efb5","...            0  invoice
# 491  [{"rowid":"3c3c139bd8467c1587a41081ad78045e","...            0  invoice
# 495  [{"rowid":"482db0ecc10b8a9984ae850c9ada9899","...            0  invoice
# 496  [{"rowid":"a7a3d70c6d17a73140918996d03c014f","...            0  invoice
# 504  [{"rowid":"47e338b3c082945eff04de6d65915ade","...      2002804  invoice
# 505  [{"rowid":"47e338b3c082945eff04de6d65915ade","...            0  invoice
# 506  [{"rowid":"2de7cf2043693db2ee898479a6e44529","...            0  invoice
# 507  [{"rowid":"03b264c595403666634ac75d828439bc","...      2002803  invoice
# 508  [{"rowid":"5bf8aaef51c6e0d363cbe554acaf3f20","...            0  invoice
# 523  [{"rowid":"17ed8abedc255908be746d245e50263a","...            0  invoice
# 525  [{"rowid":"9ce3c52fc54362e22053399d3181c638","...            0  invoice
# 526  [{"rowid":"4a64d913220fca4c33c140c6952688a8","...            0  invoice
# 528  [{"rowid":"7c33e57e3dbd8a52940fa1a963aa4a4a","...            0  invoice
# 530  [{"rowid":"9ddb9dd5d8aee9a76bf217a2a3c54833","...            0  invoice
# 538  [{"rowid":"18d10dc6e666eab6de9215ae5b3d54df","...            0  invoice
# 552  [{"rowid":"f507783927f2ec2737ba40afbd17efb5","...            0  invoice
# 553  [{"rowid":"90e1357833654983612fb05e3ec9148c","...            0  invoice
# 562  [{"rowid":"0bd65e799153554726820ca639514029","...            0  invoice
# 565  [{"rowid":"a01dfc715df9621113e91549c0ee7651","...            0  invoice
# 572  [{"rowid":"dba132f6ab6a3e3d17a8d59e82105f4c","...            0  invoice
# 604  [{"rowid":"1d6408264d31d453d556c60fe7d0459e","...            0  invoice
# 605  [{"rowid":"0b846c55b4bde6baae8c12a2e53ae8c7","...            0  invoice
# 623  [{"rowid":"7ffb4e0ece07869880d51662a2234143","...            0  invoice
# 627  [{"rowid":"d8847be3f7cc1b14e9173908bebb2106","...            0  invoice
# 640  [{"rowid":"bc5fcb0018cecacba559dc512740091b","...      2002786  invoice
# 652  [{"rowid":"a7a3d70c6d17a73140918996d03c014f","...            0  invoice
# 708  [{"rowid":"64a7157cf3932bf74755aa3cf586f2ec","...            0  invoice
# 711  [{"rowid":"2c6a0bae0f071cbbf0bb3d5b11d90a82","...            0  invoice
# 712  [{"rowid":"043c2ec6c6390dd0ac5519190a57c88c","...            0  invoice
#
#        sales             purchase_info
# 39     Karen                ONLINE5818
# 42    Others                ONLINE5817
# 45    Laurel                         D
# 48    Others                ONLINE5816
# 50     Helen                ONLINE5814
# 55     Karen                        PH
# 56     Helen           PH (MADAM PLUM)
# 59     Helen                ONLINE5811
# 60   Pauline                ONLINE5810
# 63     Helen                ONLINE5807
# 64     Helen                ONLINE5806
# 65      Lois                    CREDIT
# 66    Others  PERSONAL (PICKUP & PAID)
# 68    Others                ONLINE5804
# 69    Laurel                    CREDIT
# 70     Helen                    CREDIT
# 71   Pauline                         D
# 72    Laurel                         D
# 73      Lois                ONLINE5803
# 75    Laurel                         D
# 76     Karen                ONLINE5801
# 79    Others                ONLINE5798
# 80    Laurel             ONLINE5797 EM
# 81     Karen                ONLINE5796
# 82     Helen                ONLINE5795
# 84      Lois                         D
# 85      Lois                         D
# 86     Karen                         D
# 87     Karen                ONLINE5793
# 89      Lois                ONLINE5792
# ..       ...                       ...
# 478    Helen                ONLINE5626
# 489   Laurel                ONLINE5615
# 491    Helen                ONLINE5613
# 495    Karen                ONLINE5610
# 496   Others                ONLINE5609
# 504  Pauline                         D
# 505  Pauline       PROFORMA INVOICE(D)
# 506   Laurel                         D
# 507   Laurel                         D
# 508    Helen                         D
# 523    Helen                ONLINE5601
# 525    Helen                         D
# 526    Helen                         D
# 528    Helen                         D
# 530    Helen                         D
# 538     Lois                ONLINE5597
# 552     Lois                ONLINE5591
# 553    Karen                ONLINE5590
# 562     Lois                ONLINE5584
# 565    Helen                         D
# 572    Helen                ONLINE5577
# 604     Lois                         D
# 605   Laurel                         D
# 623    Helen                         D
# 627     Lois                         D
# 640   Laurel                         D
# 652     Lois                ONLINE5544
# 708    Helen                         D
# 711    Helen                         D
# 712    Helen                         D
#
# [431 rows x 18 columns]

# %%
total_orders_0616 = len(jun2016)
total_orders_0616
# Out:
# 431

# %%
avg_order_cost = jun2016.total.mean()
avg_order_cost
# Out:
# 334.1693503480278

# %%
total_order_cost_0616 = jun2016.total.sum()
total_order_cost_0616
# Out:
# 144026.99

# %%
#find out the total numbers on each day that month
jun16_bydate = jun2016.groupby('date')
#sum up the numeric data for each day
jun16_bydate['subtotal', 'freight', 'tax', 'total','paid', 'delivered'].sum()
# Out:
#                      subtotal  freight      tax     total  paid  delivered
# date
# 2016-06-01 00:00:00  17414.00    499.0  2687.06  20600.06    11         55
# 2016-06-02 00:00:00   6408.50    198.0   991.00   7597.50     2         20
# 2016-06-03 00:00:00   6480.25    209.0  1003.43   7692.68     1         18
# 2016-06-07 00:00:00   7585.00    194.0  1166.89   8945.89     4         28
# 2016-06-08 00:00:00   7479.00    230.0  1156.38   8865.38     2         20
# 2016-06-09 00:00:00   7433.00    221.0  1148.13   8802.13     4         25
# 2016-06-10 00:00:00   7115.50    194.0  1096.48   8405.98     0         22
# 2016-06-13 00:00:00  12233.95    256.0  1873.56  14363.51     5         27
# 2016-06-14 00:00:00   5409.50    260.0   850.46   6519.96     1         28
# 2016-06-15 00:00:00   6509.50    256.0  1014.84   7780.34    10         33
# 2016-06-16 00:00:00  12416.00    440.0  1928.43  14784.43     2         39
# 2016-06-17 00:00:00   4640.50    248.0   733.31   5621.81     1         25
# 2016-06-20 00:00:00   4786.00    160.0   741.92   5687.92     4         18
# 2016-06-21 00:00:00   4624.40    181.0   720.84   5526.24     0         17
# 2016-06-22 00:00:00   3949.70    139.0   613.33   4702.03     1         16
# 2016-06-23 00:00:00    684.00     56.0   111.01    851.01     0          4
# 2016-06-24 00:00:00   2084.50     65.0   322.44   2471.94     0          7
# 2016-06-27 00:00:00   2384.00     87.0   370.66   2841.66     1         11
# 2016-06-28 00:00:00    199.00     12.0    31.65    242.65     0          2
# 2016-06-29 00:00:00   1116.50     72.0   178.29   1366.79     0          7
# 2016-06-30 00:00:00    283.50     27.0    46.58    357.08     0          4

# %%
#Invoices per day in June
jun16_bydate.total.sum().plot.bar()

# %%
#Goal: I want to graph the total of each month over the last 2 years

#add year and month columns to dataset
make_year = lambda x : x[:4]
make_month = lambda x : x[5:7]

data['Year'] = data['date'].apply(make_year)
data['Month'] = data['date'].apply(make_month)
data[['Year', 'Month']]
# Out:
#       Year Month
# 0     2016    07
# 1     2016    07
# 2     2016    07
# 3     2016    07
# 4     2016    07
# 5     2016    07
# 6     2016    07
# 7     2016    07
# 8     2016    07
# 9     2016    07
# 10    2016    07
# 11    2016    07
# 12    2016    07
# 13    2016    07
# 14    2016    07
# 15    2016    07
# 16    2016    07
# 17    2016    07
# 18    2016    07
# 19    2016    07
# 20    2016    07
# 21    2016    07
# 22    2016    07
# 23    2016    07
# 24    2016    07
# 25    2016    07
# 26    2016    07
# 27    2016    07
# 28    2016    07
# 29    2016    07
# ...    ...   ...
# 6380  2014    07
# 6381  2014    07
# 6382  2014    07
# 6383  2014    07
# 6384  2014    07
# 6385  2014    07
# 6386  2014    07
# 6387  2014    07
# 6388  2014    07
# 6389  2014    07
# 6390  2014    07
# 6391  2014    07
# 6392  2014    07
# 6393  2014    07
# 6394  2014    07
# 6395  2014    07
# 6396  2014    07
# 6397  2014    07
# 6398  2014    07
# 6399  2014    07
# 6400  2014    07
# 6401  2014    07
# 6402  2014    07
# 6403  2014    07
# 6404  2014    07
# 6405  2014    07
# 6406  2014    07
# 6407  2014    07
# 6408  2014    07
# 6409  2014    07
#
# [6410 rows x 2 columns]

# %%
year_month = data.groupby(['Year', 'Month'])
year_month['total'].sum().plot.bar(title = 'Invoice sum by month')

# %%
#Data seems to follow a pattern based on month of year. Looks promising.
#Seems like sales are growing, a good sign
#The month of August seems to have an interesting dip. Maybe because it's the beginning of a new financial year?

# %%
#Try regression, but I'm not sure how well it will work on this wave-form type data..
numerical_data = data[['subtotal', 'freight', 'tax', 'total', 'discount', 'paid', 'delivered']]
numerical_data.corr()
# Out:
#            subtotal   freight       tax     total  discount      paid  \
# subtotal   1.000000  0.493163  0.999865  0.999865  0.113026 -0.035617
# freight    0.493163  1.000000  0.507406  0.507402 -0.072046  0.017934
# tax        0.999865  0.507406  1.000000  1.000000  0.110593 -0.034939
# total      0.999865  0.507402  1.000000  1.000000  0.110595 -0.034940
# discount   0.113026 -0.072046  0.110593  0.110595  1.000000 -0.005890
# paid      -0.035617  0.017934 -0.034939 -0.034940 -0.005890  1.000000
# delivered -0.008642 -0.039454 -0.009306 -0.009306  0.002412  0.074890
#
#            delivered
# subtotal   -0.008642
# freight    -0.039454
# tax        -0.009306
# total      -0.009306
# discount    0.002412
# paid        0.074890
# delivered   1.000000

# %%
pd.scatter_matrix(numerical_data, figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x117893e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117b19d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117bb8390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117b42ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117cb7650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117d3b910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117bac8d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x117e55290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117eb0a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f883850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x131c71450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f98f6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fa12590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fa9a350>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11fb2c350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fa20c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fe2a8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11febac10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ff26bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x131cd63d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x131cf70d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x131c81650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1335fb4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132d99390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132c27550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x139906410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1397ec890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x139929e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1396c43d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1396b8690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1141f0cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1332ddc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x133337910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1333c5b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x133677a10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1351a58d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x135728a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13578c950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13900cdd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1357b9f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1390fc910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13927ebd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1392ef250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1394701d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1394bce50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x139557110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1395cbf50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x139638e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x139bfcfd0>]], dtype=object)

# %%
#The above graph really just says the obvious.
#Makes sense that tax, frieght, subtotal and total are all related
#Let's check the sums
ym_df = year_month.aggregate(numpy.sum)[['total', 'freight','paid','delivered']]
ym_df
# Out:
#                 total  freight  paid  delivered
# Year Month
# 2014 07      91440.74   3169.5   306        307
#      08      53093.28   1854.0   186        188
#      09     106798.39   2987.0   323        323
#      10      83883.93   2116.0   245        248
#      11      59162.95   1733.0   216        217
#      12      52141.18   1620.0   183        184
# 2015 01      34406.93   1194.0   122        122
#      02      24735.48    879.0    90         90
#      03      88169.00   2750.0   246        246
#      04     124176.68   4216.0   332        333
#      05     138842.21   4203.0   395        398
#      06     136445.39   4538.0   439        441
#      07     108116.83   3138.0   352        352
#      08      59592.40   1857.0   206        207
#      09      93955.27   2588.0   285        285
#      10      85808.01   1915.0   241        241
#      11      72552.38   1936.5   240        243
#      12      53568.93   1458.0   192        192
# 2016 01      32745.69    866.0   101        103
#      02      38683.52   1200.0   128        131
#      03     103232.08   2356.5   212        222
#      04     151210.25   3973.0   366        398
#      05     150842.25   3744.0   314        445
#      06     144026.99   4004.0    49        426
#      07      24414.38    634.0     1         62

# %%
ym_df.corr()
# Out:
#               total   freight      paid  delivered
# total      1.000000  0.958836  0.716925   0.969460
# freight    0.958836  1.000000  0.758311   0.960609
# paid       0.716925  0.758311  1.000000   0.750883
# delivered  0.969460  0.960609  0.750883   1.000000

# %%
pd.scatter_matrix(ym_df, figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x122c95710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1357cd1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fa3b810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13303f790>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x117b42b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13196c250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122c62a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x139f37fd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1399f3990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13daf4650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13db7c8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13dd0d750>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13dd76610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13ddf37d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13de53690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13deceb10>]], dtype=object)

# %%
#It's not too interesting doing a regression on these variables
#But we can predict how much freight will cost - although this could probably be looked up easily too...
totals = ym_df.loc[ : , ['total']]
freight = ym_df.freight

# %%
import sklearn.linear_model
r = sklearn.linear_model.RANSACRegressor()

# %%
r.fit(totals, freight)
# Out:
# RANSACRegressor(base_estimator=None, is_data_valid=None, is_model_valid=None,
#         max_trials=100, min_samples=None, random_state=None,
#         residual_metric=None, residual_threshold=None, stop_n_inliers=inf,
#         stop_probability=0.99, stop_score=inf)

# %%
#test against original data:
predictions = r.predict(totals)
predictions
# Out:
# array([ 2629.66445118,  1568.97191292,  3054.45776892,  2420.64273292,
#         1736.85926918,  1542.63678236,  1052.10659739,   784.59383777,
#         2539.16796967,  3535.14208363,  3940.79132978,  3874.49517641,
#         3090.92588103,  1748.73787628,  2699.21646866,  2473.86287577,
#         2107.21152961,  1582.12841418,  1006.15662125,  1170.39727694,
#         2955.81346742,  4282.891895  ,  4272.71299778,  4084.20258723,
#          775.71219674])

# %%
#draw the original data points
plt.scatter(x=ym_df.total, y=ym_df.freight)
#draw the prediction as a line to see how good the regression was
plt.plot(ym_df.total, predictions, color = 'red')
plt.xlabel('Totals')
plt.ylabel('Freight')

# %%
#gets the gradient of the line
r.estimator_.coef_ 
#for each dollar sold, 0.02 is spent on freight
# Out:
# array([ 0.02766005])

# %%
#minimum freight per month
r.estimator_.intercept_
# Out:
# 100.40930334470568

# %%
#How much would the monthly freight cost when total invoices are 100k?
r.predict(100000)
# Out:
# array([ 2866.41398336])

# %%
#what about a $200000 one?
r.predict(200000)
# Out:
# array([ 5632.41866337])

# %%
#Next steps
# - Add year/month data to orders, so I can map out how well each product has been doing the past two years
# - Scrape webpages & add another dataframe for product info. Includes additional data like colour & materials
# - Add more data for 2012 - 2014
# - Find the monthly trend in invoices day-by-day. Regress each month and see if there is a pattern in sales.

#Some potentially interesting questions to explore:
# - What is the business growth? I need to learn how to regress when the x-axis is time...
# - Given the month & year, how many of each product should we prepare in stock?
# - Predict the trend, lifetime, or rise & fall of each product and set price accordingly
# - Trends in colour. Is this affected by the season/month?
